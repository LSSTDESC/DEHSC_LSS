# %% [markdown]
# <b> Trial Diagnostic Plots on HSC data </b>
#
# Author: Camille Avestruz
#
# Date Created: December 2017

# %%
from astropy.io import fits

# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
#  Set the HSC data file in fits format
fitsfile='/home/babyostrich/data/LSSTDESC/HSC/HSC_WIDE_GAMA15H_forced.fits'

# %%
# Open and inspect the file.  This fits file has two blocks, the data is in block 1.
# Refer to astropy documentation: http://docs.astropy.org/en/stable/io/fits/
hdulist = fits.open(fitsfile)

# Check that the 0th block contains data
print "0th block is image: ",hdulist[0].is_image
type(hdulist[1].data)
# Out:
# 0th block is image:  True
# astropy.io.fits.fitsrec.FITS_rec

# %%
print hdulist[0].header
print hdulist[1].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  END
# XTENSION= 'BINTABLE'           / binary table extension                         BITPIX  =                    8 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                  546 / length of dimension 1                          NAXIS2  =              7681225 / length of dimension 2                          PCOUNT  =                    0 / number of group parameters                     GCOUNT  =                    1 / number of groups                               TFIELDS =                  196 / number of table fields                         TTYPE1  = 'object_id'                                                           TFORM1  = 'K       '                                                            TTYPE2  = 'object_id_isnull'                                                    TFORM2  = 'L       '                                                            TTYPE3  = 'ra      '                                                            TFORM3  = 'D       '                                                            TTYPE4  = 'ra_isnull'                                                           TFORM4  = 'L       '                                                            TTYPE5  = 'dec     '                                                            TFORM5  = 'D       '                                                            TTYPE6  = 'dec_isnull'                                                          TFORM6  = 'L       '                                                            TTYPE7  = 'tract   '                                                            TFORM7  = 'J       '                                                            TTYPE8  = 'tract_isnull'                                                        TFORM8  = 'L       '                                                            TTYPE9  = 'patch   '                                                            TFORM9  = 'J       '                                                            TTYPE10 = 'patch_isnull'                                                        TFORM10 = 'L       '                                                            TTYPE11 = 'merge_peak_g'                                                        TFORM11 = 'L       '                                                            TTYPE12 = 'merge_peak_g_isnull'                                                 TFORM12 = 'L       '                                                            TTYPE13 = 'merge_peak_r'                                                        TFORM13 = 'L       '                                                            TTYPE14 = 'merge_peak_r_isnull'                                                 TFORM14 = 'L       '                                                            TTYPE15 = 'merge_peak_i'                                                        TFORM15 = 'L       '                                                            TTYPE16 = 'merge_peak_i_isnull'                                                 TFORM16 = 'L       '                                                            TTYPE17 = 'merge_peak_z'                                                        TFORM17 = 'L       '                                                            TTYPE18 = 'merge_peak_z_isnull'                                                 TFORM18 = 'L       '                                                            TTYPE19 = 'merge_peak_y'                                                        TFORM19 = 'L       '                                                            TTYPE20 = 'merge_peak_y_isnull'                                                 TFORM20 = 'L       '                                                            TTYPE21 = 'gcountinputs'                                                        TFORM21 = 'I       '                                                             ...

# %%
# Let's collect the columns to view, and the data in a table
data_columns = hdulist[1].columns
table_data = hdulist[1].data

# %%
# data_columns contains a list of strings labeling the columns
# You should cross-check this with the schema descriptions here: 
#  https://hsc-release.mtk.nao.ac.jp/schema/#:legend
print data_columns.info()
# Out:
# name:
#     ['object_id', 'object_id_isnull', 'ra', 'ra_isnull', 'dec', 'dec_isnull', 'tract', 'tract_isnull', 'patch', 'patch_isnull', 'merge_peak_g', 'merge_peak_g_isnull', 'merge_peak_r', 'merge_peak_r_isnull', 'merge_peak_i', 'merge_peak_i_isnull', 'merge_peak_z', 'merge_peak_z_isnull', 'merge_peak_y', 'merge_peak_y_isnull', 'gcountinputs', 'gcountinputs_isnull', 'rcountinputs', 'rcountinputs_isnull', 'icountinputs', 'icountinputs_isnull', 'zcountinputs', 'zcountinputs_isnull', 'ycountinputs', 'ycountinputs_isnull', 'iflags_pixel_bright_object_center', 'iflags_pixel_bright_object_center_isnull', 'iflags_pixel_bright_object_any', 'iflags_pixel_bright_object_any_isnull', 'iclassification_extendedness', 'iclassification_extendedness_isnull', 'a_g', 'a_g_isnull', 'a_r', 'a_r_isnull', 'a_i', 'a_i_isnull', 'a_z', 'a_z_isnull', 'a_y', 'a_y_isnull', 'gflux_psf', 'gflux_psf_isnull', 'rflux_psf', 'rflux_psf_isnull', 'iflux_psf', 'iflux_psf_isnull', 'zflux_psf', 'zflux_psf_isnull', 'yflux_psf', 'yflux_psf_isnull', 'gflux_psf_err', 'gflux_psf_err_isnull', 'rflux_psf_err', 'rflux_psf_err_isnull', 'iflux_psf_err', 'iflux_psf_err_isnull', 'zflux_psf_err', 'zflux_psf_err_isnull', 'yflux_psf_err', 'yflux_psf_err_isnull', 'gflux_psf_flags', 'gflux_psf_flags_isnull', 'rflux_psf_flags', 'rflux_psf_flags_isnull', 'iflux_psf_flags', 'iflux_psf_flags_isnull', 'zflux_psf_flags', 'zflux_psf_flags_isnull', 'yflux_psf_flags', 'yflux_psf_flags_isnull', 'gmag_psf', 'gmag_psf_isnull', 'rmag_psf', 'rmag_psf_isnull', 'imag_psf', 'imag_psf_isnull', 'zmag_psf', 'zmag_psf_isnull', 'ymag_psf', 'ymag_psf_isnull', 'gmag_psf_err', 'gmag_psf_err_isnull', 'rmag_psf_err', 'rmag_psf_err_isnull', 'imag_psf_err', 'imag_psf_err_isnull', 'zmag_psf_err', 'zmag_psf_err_isnull', 'ymag_psf_err', 'ymag_psf_err_isnull', 'gflux_aperture10', 'gflux_aperture10_isnull', 'rflux_aperture10', 'rflux_aperture10_isnull', 'iflux_aperture10', 'iflux_aperture10_isnull', 'zflux_aperture10', 'zflux_aperture10_isnull', 'yflux_aperture10', 'yflux_aperture10_isnull', 'gflux_aperture10_err', 'gflux_aperture10_err_isnull', 'rflux_aperture10_err', 'rflux_aperture10_err_isnull', 'iflux_aperture10_err', 'iflux_aperture10_err_isnull', 'zflux_aperture10_err', 'zflux_aperture10_err_isnull', 'yflux_aperture10_err', 'yflux_aperture10_err_isnull', 'gflux_aperture_flags', 'gflux_aperture_flags_isnull', 'rflux_aperture_flags', 'rflux_aperture_flags_isnull', 'iflux_aperture_flags', 'iflux_aperture_flags_isnull', 'zflux_aperture_flags', 'zflux_aperture_flags_isnull', 'yflux_aperture_flags', 'yflux_aperture_flags_isnull', 'gmag_aperture10', 'gmag_aperture10_isnull', 'rmag_aperture10', 'rmag_aperture10_isnull', 'imag_aperture10', 'imag_aperture10_isnull', 'zmag_aperture10', 'zmag_aperture10_isnull', 'ymag_aperture10', 'ymag_aperture10_isnull', 'gmag_aperture10_err', 'gmag_aperture10_err_isnull', 'rmag_aperture10_err', 'rmag_aperture10_err_isnull', 'imag_aperture10_err', 'imag_aperture10_err_isnull', 'zmag_aperture10_err', 'zmag_aperture10_err_isnull', 'ymag_aperture10_err', 'ymag_aperture10_err_isnull', 'gcmodel_flux', 'gcmodel_flux_isnull', 'rcmodel_flux', 'rcmodel_flux_isnull', 'icmodel_flux', 'icmodel_flux_isnull', 'zcmodel_flux', 'zcmodel_flux_isnull', 'ycmodel_flux', 'ycmodel_flux_isnull', 'gcmodel_flux_err', 'gcmodel_flux_err_isnull', 'rcmodel_flux_err', 'rcmodel_flux_err_isnull', 'icmodel_flux_err', 'icmodel_flux_err_isnull', 'zcmodel_flux_err', 'zcmodel_flux_err_isnull', 'ycmodel_flux_err', 'ycmodel_flux_err_isnull', 'gcmodel_flux_flags', 'gcmodel_flux_flags_isnull', 'rcmodel_flux_flags', 'rcmodel_flux_flags_isnull', 'icmodel_flux_flags', 'icmodel_flux_flags_isnull', 'zcmodel_flux_flags', 'zcmodel_flux_flags_isnull', 'ycmodel_flux_flags', 'ycmodel_flux_flags_isnull', 'gcmodel_mag', 'gcmodel_mag_isnull', 'rcmodel_mag', 'rcmodel_mag_isnull', 'icmodel_mag', 'icmodel_mag_isnull', 'zcmodel_mag', 'zcmodel_mag_isnull', 'ycmodel_mag', 'ycmodel_mag_isnull', 'gcmodel_mag_err', 'gcmodel_mag_err_isnull', 'rcmodel_mag_er ...
# format:
#     ['K', 'L', 'D', 'L', 'D', 'L', 'J', 'L', 'J', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'I', 'L', 'I', 'L', 'I', 'L', 'I', 'L', 'I', 'L', 'L', 'L', 'L', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'D', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L', 'E', 'L']
# unit:
#     ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# null:
#     ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# bscale:
#     ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# bzero:
#     ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# disp:
#     ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# start:
#     ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# dim:
#     ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# None

# %%
# As a first step, let's plot the ra and dec.  Note, normally we'd need to 
# select out items where ra or dec is null with a mask.  But, there are ra and dec values for
# all items, so the np.where method returns empty arrays.

import numpy as np

#  Check to see that we have all ra and dec for plotting
print np.where(table_data['dec_isnull'])
print np.where(table_data['ra_isnull'])
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
# Let's plot a subset of the ra and dec to get an idea of the area coverage of this 
# subset of the data
plt.scatter(table_data['dec'][::100], table_data['ra'][::100],s=0.001)
plt.xlabel('dec',fontsize='xx-large')
plt.ylabel('ra',fontsize='xx-large')

# %%
# Let's now compare histogram of fluxes and magnitudes depending on how that is calculated. 
# Some values are nan - a quick min/max check on the table column values would show this.

column_name = 'gcmodel_flux'

plt.hist(table_data[column_name][~np.isnan(table_data[column_name])],bins=99)
plt.yscale('log', nonposy='clip')
plt.xlabel('G Flux $[erg s^{-1} cm^{-2} Hz^{-1}]$',fontsize='xx-large')

# %%
# Let's check the magnitudes - remove nan and infinite values!
column_label = 'gcmodel_mag'

# Selecting for "np.isfinite" values gets rid of both nan and inf values.
plt.hist(table_data[column_label][np.isfinite(table_data[column_label])],bins=99)
plt.yscale('log', nonposy='clip')
plt.xlabel('G Magnitude',fontsize='xx-large')

# %%
# Let's generalize this for all grizy fluxes and magnitudes

def histogram_column_finite_vals(table_data, column_label, annotation) :
    '''Plot a histogram on an axis using a column from the table data.'''
    plt.hist(table_data[column_label][np.isfinite(table_data[column_label])],
             bins=99,normed=True)
    plt.yscale('log',nonposy='clip')
    plt.annotate(annotation, (0.6,0.8), xycoords='figure fraction')

for column_label, annotation in \
    zip([c+'cmodel_flux' for c in ['g', 'r', 'i', 'z', 'y']],
        [c+' Flux' for c in ['g', 'r', 'i', 'z', 'y']]) :
        histogram_column_finite_vals(table_data, column_label, annotation)
        plt.show()

# %%
for column_label, annotation in \
    zip([c+'cmodel_mag' for c in ['g', 'r', 'i', 'z', 'y']],
        [c+' Magnitude' for c in ['g', 'r', 'i', 'z', 'y']]) :
        histogram_column_finite_vals(table_data, column_label, annotation)
        plt.show()

# %% [markdown]
# As a next example diagnostic plot, let's look at a color-color plot.

# %%
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
import numpy as np

g = 'gcmodel_mag'
r = 'rcmodel_mag'
i = 'icmodel_mag'

r_i_diff = (table_data[r] - table_data[i])
g_r_diff = (table_data[g] - table_data[r])
r_i_diff_fin = r_i_diff[np.isfinite(r_i_diff) & np.isfinite(g_r_diff)]
g_r_diff_fin = g_r_diff[np.isfinite(r_i_diff) & np.isfinite(g_r_diff)]

plt.hist2d(g_r_diff_fin, r_i_diff_fin, bins=99, norm=LogNorm())
plt.colorbar()
plt.xlabel('g-r',fontsize='xx-large')
plt.ylabel('r-i',fontsize='xx-large')

plt.show()
# Out:
# /home/babyostrich/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:9: RuntimeWarning: invalid value encountered in subtract
# /home/babyostrich/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:10: RuntimeWarning: invalid value encountered in subtract

# %% [markdown]
# Let's now overlay the magnitude distribution for objects detected in more than one band, looking at the distribution in the peak color.

# %% [markdown]
# Let's now look at psf_mag - cmodel_mag as a function of psf_mag.  This is one quick approximate differentiator of stars and galaxies.  If an object is a star, there should be no difference between psf_mag and cmodel_mag, so these objects lie along the x-axis.

# %%
def plot_stargal_diagnostic1(color, table_data) :
    p_c_diff = table_data[color+'mag_psf'] - table_data[color+'cmodel_mag']
    psf_mag = table_data[color+'mag_psf']
    
    p_c_diff_isfin = p_c_diff[np.isfinite(p_c_diff) & np.isfinite(psf_mag)]
    psf_mag_isfin = psf_mag[np.isfinite(p_c_diff) & np.isfinite(psf_mag)]
    
    plt.hist2d(psf_mag_isfin, p_c_diff_isfin, bins=99, norm=LogNorm())
    plt.colorbar()
    plt.xlabel('PSF Mag',fontsize='xx-large')
    plt.ylabel('PSF Mag - cmodel Mag',fontsize='xx-large')
    plt.annotate(color+' band', (0.2,0.8), xycoords='figure fraction',fontsize='large')

    plt.show()

# %%
for color in ['g', 'r', 'i', 'z', 'y' ]:
    plot_stargal_diagnostic1(color, table_data)
